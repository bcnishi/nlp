# %%
import nltk

# %%
#nltk.download()

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import mac_morpho
from nltk.tag import UnigramTagger
from nltk.tag import DefaultTagger
from nltk import bigrams
from nltk import trigrams
from nltk import ngrams

# %%
corpus = open("corpus_teste.txt", "r", encoding="utf-8").read()

# %% [markdown]
# ## Exercício 1</br>
# Escolha um corpus qualquer e, usando as funções do NLTK, faça:</br>
# - a) Tokenize o corpus inteiro (palavras, números e pontuações);</br>
# - b) Verifique a quantidade de tokens do corpus;</br>
# - c) Tokenize o corpus apenas por suas palavras;</br>
# - d) Verifique a quantidade de palavras do corpus;</br>
# - e) Verifique a frequência de palavras no corpus;</br>
# - f) Verifique quais são as 5, 10 e 15 palavras mais frequentes do corpus;</br>
# - g) Extraia as stopwords do NLTK (não do corpus ainda);</br>
# - h) Verifique a frequência dos tokens sem stopwords do corpus.</br>

# %%
#a) Tokenize o corpus inteiro (palavras, números e pontuações)
all_tokens = nltk.word_tokenize(corpus)

# %%
#b) Verifique a quantidade de tokens do corpus
print(f'Quantidade de tokens do corpus: {len(all_tokens)}')
# Out:
# Quantidade de tokens do corpus: 862

# %%
#c) Tokenize o corpus apenas por suas palavras
tokenizer = RegexpTokenizer(r'[A-z]\w*') #return word characters
word_tokens =  tokenizer.tokenize(corpus)

# %%
#d) Verifique a quantidade de palavras do corpus
print(f'Quantidade de palavras do corpus: {len(word_tokens)}')
# Out:
# Quantidade de palavras do corpus: 726

# %%
#e) Verifique a frequência de palavras no corpus
frequencia = nltk.FreqDist(word_tokens)
frequencia.most_common()
# Out:
# [('de', 34),
#  ('o', 26),
#  ('a', 23),
#  ('e', 21),
#  ('para', 16),
#  ('jardas', 15),
#  ('do', 12),
#  ('na', 12),
#  ('Giants', 11),
#  ('um', 11),
#  ('os', 10),
#  ('Patriots', 10),
#  ('Manning', 10),
#  ('uma', 10),
#  ('linha', 10),
#  ('com', 8),
#  ('no', 7),
#  ('O', 7),
#  ('que', 7),
#  ('dos', 7),
#  ('bola', 7),
#  ('da', 6),
#  ('em', 6),
#  ('vez', 6),
#  ('zone', 6),
#  ('New', 5),
#  ('Com', 5),
#  ('passe', 5),
#  ('York', 5),
#  ('Brady', 5),
#  ('A', 5),
#  ('avanço', 5),
#  ('mas', 5),
#  ('Super', 4),
#  ('Bowl', 4),
#  ('England', 4),
#  ('Eli', 4),
#  ('segundos', 4),
#  ('fim', 4),
#  ('touchdown', 4),
#  ('time', 4),
#  ('Nova', 4),
#  ('não', 4),
#  ('jogo', 4),
#  ('achou', 4),
#  ('end', 4),
#  ('título', 3),
#  ('história', 3),
#  ('ao', 3),
#  ('primeira', 3),
#  ('chegou', 3),
#  ('Os', 3),
#  ('posse', 3),
#  ('passes', 3),
#  ('curtos', 3),
#  ('red', 3),
#  ('campanha', 3),
#  ('ataque', 3),
#  ('avançou', 3),
#  ('período', 3),
# ...

# %%
#f) Verifique quais são as 5, 10 e 15 palavras mais frequentes do corpus
frequencia.most_common(5)
frequencia.most_common(10)
frequencia.most_common(15)
# Out:
# [('de', 34),
#  ('o', 26),
#  ('a', 23),
#  ('e', 21),
#  ('para', 16),
#  ('jardas', 15),
#  ('do', 12),
#  ('na', 12),
#  ('Giants', 11),
#  ('um', 11),
#  ('os', 10),
#  ('Patriots', 10),
#  ('Manning', 10),
#  ('uma', 10),
#  ('linha', 10)]

# %%
#g) Extraia as stopwords do NLTK (não do corpus ainda)
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
#h) Verifique a frequência dos tokens sem stopwords do corpus
no_stopwords = [x for x in word_tokens if x.lower() not in stopwords]
freq_no_stopwords = nltk.FreqDist(no_stopwords)
freq_no_stopwords.most_common()
# Out:
# [('jardas', 15),
#  ('Giants', 11),
#  ('Patriots', 10),
#  ('Manning', 10),
#  ('linha', 10),
#  ('bola', 7),
#  ('vez', 6),
#  ('zone', 6),
#  ('New', 5),
#  ('passe', 5),
#  ('York', 5),
#  ('Brady', 5),
#  ('avanço', 5),
#  ('Super', 4),
#  ('Bowl', 4),
#  ('England', 4),
#  ('Eli', 4),
#  ('segundos', 4),
#  ('fim', 4),
#  ('touchdown', 4),
#  ('time', 4),
#  ('Nova', 4),
#  ('jogo', 4),
#  ('achou', 4),
#  ('end', 4),
#  ('título', 3),
#  ('história', 3),
#  ('primeira', 3),
#  ('chegou', 3),
#  ('posse', 3),
#  ('passes', 3),
#  ('curtos', 3),
#  ('red', 3),
#  ('campanha', 3),
#  ('ataque', 3),
#  ('avançou', 3),
#  ('período', 3),
#  ('XLII', 2),
#  ('temporada', 2),
#  ('Plaxico', 2),
#  ('Burress', 2),
#  ('anotou', 2),
#  ('Tom', 2),
#  ('companhia', 2),
#  ('fazer', 2),
#  ('NFL', 2),
#  ('ano', 2),
#  ('vitória', 2),
#  ('porém', 2),
#  ('máximo', 2),
#  ('logo', 2),
#  ('field', 2),
#  ('goal', 2),
#  ('entrou', 2),
#  ('Maroney', 2),
#  ('deixando', 2),
# ...

# %% [markdown]
# ## Exercício 2
# Escolha um corpus qualquer e, usando as funções do NLTK, faça:
# - a) Extraia todos os bigramas do corpus;
# - b) Extraia todos os trigramas do corpus;
# - c) Extraia todos os 4-gramas do corpus;
# - d) Retorne as entidades nomeadas do corpus, usando os bigramas e trigramas;
# - e) Escolha 3 palavras do seu corpus e faça o stemming delas;
# - f) Separe uma sentença do seu corpus e retorne todas as classes gramaticais das palavras da sentença. Analise se o etiquetador acertou todas as classes gramaticais;
# - g) Retorne as classes gramaticais de todas as palavras do seu corpus;
# - h) Retorne as entidades nomeadas do seu corpus, usando a técnica de chunking.

# %%
#a) Extraia todos os bigramas do corpus
bigramas = list(nltk.bigrams(no_stopwords))
bigramas
# Out:
# [('Giants', 'batem'),
#  ('batem', 'Patriots'),
#  ('Patriots', 'Super'),
#  ('Super', 'Bowl'),
#  ('Bowl', 'XLII'),
#  ('XLII', 'Azarões'),
#  ('Azarões', 'acabam'),
#  ('acabam', 'invencibilidade'),
#  ('invencibilidade', 'New'),
#  ('New', 'England'),
#  ('England', 'ficam'),
#  ('ficam', 'título'),
#  ('título', 'temporada'),
#  ('temporada', 'h07m'),
#  ('h07m', 'Atualizado'),
#  ('Atualizado', 'h49m'),
#  ('h49m', 'passe'),
#  ('passe', 'Eli'),
#  ('Eli', 'Manning'),
#  ('Manning', 'Plaxico'),
#  ('Plaxico', 'Burress'),
#  ('Burress', 'segundos'),
#  ('segundos', 'fim'),
#  ('fim', 'New'),
#  ('New', 'York'),
#  ('York', 'Giants'),
#  ('Giants', 'anotou'),
#  ('anotou', 'touchdown'),
#  ('touchdown', 'decisivo'),
#  ('decisivo', 'derrubou'),
#  ('derrubou', 'favorito'),
#  ('favorito', 'New'),
#  ('New', 'England'),
#  ('England', 'Patriots'),
#  ('Patriots', 'neste'),
#  ('neste', 'domingo'),
#  ('domingo', 'Glendale'),
#  ('Glendale', 'Super'),
#  ('Super', 'Bowl'),
# ...

# %%
#b) Extraia todos os trigramas do corpus
trigramas = list(nltk.trigrams(no_stopwords))
trigramas
# Out:
# [('Giants', 'batem', 'Patriots'),
#  ('batem', 'Patriots', 'Super'),
#  ('Patriots', 'Super', 'Bowl'),
#  ('Super', 'Bowl', 'XLII'),
#  ('Bowl', 'XLII', 'Azarões'),
#  ('XLII', 'Azarões', 'acabam'),
#  ('Azarões', 'acabam', 'invencibilidade'),
#  ('acabam', 'invencibilidade', 'New'),
#  ('invencibilidade', 'New', 'England'),
#  ('New', 'England', 'ficam'),
#  ('England', 'ficam', 'título'),
#  ('ficam', 'título', 'temporada'),
#  ('título', 'temporada', 'h07m'),
#  ('temporada', 'h07m', 'Atualizado'),
#  ('h07m', 'Atualizado', 'h49m'),
#  ('Atualizado', 'h49m', 'passe'),
#  ('h49m', 'passe', 'Eli'),
#  ('passe', 'Eli', 'Manning'),
#  ('Eli', 'Manning', 'Plaxico'),
#  ('Manning', 'Plaxico', 'Burress'),
#  ('Plaxico', 'Burress', 'segundos'),
#  ('Burress', 'segundos', 'fim'),
#  ('segundos', 'fim', 'New'),
#  ('fim', 'New', 'York'),
#  ('New', 'York', 'Giants'),
#  ('York', 'Giants', 'anotou'),
#  ('Giants', 'anotou', 'touchdown'),
#  ('anotou', 'touchdown', 'decisivo'),
# ...

# %%
#c) Extraia todos os 4-gramas do corpus
four_gramas = list(nltk.ngrams(no_stopwords,4))
four_gramas
# Out:
# [('Giants', 'batem', 'Patriots', 'Super'),
#  ('batem', 'Patriots', 'Super', 'Bowl'),
#  ('Patriots', 'Super', 'Bowl', 'XLII'),
#  ('Super', 'Bowl', 'XLII', 'Azarões'),
#  ('Bowl', 'XLII', 'Azarões', 'acabam'),
#  ('XLII', 'Azarões', 'acabam', 'invencibilidade'),
#  ('Azarões', 'acabam', 'invencibilidade', 'New'),
#  ('acabam', 'invencibilidade', 'New', 'England'),
#  ('invencibilidade', 'New', 'England', 'ficam'),
#  ('New', 'England', 'ficam', 'título'),
#  ('England', 'ficam', 'título', 'temporada'),
#  ('ficam', 'título', 'temporada', 'h07m'),
#  ('título', 'temporada', 'h07m', 'Atualizado'),
#  ('temporada', 'h07m', 'Atualizado', 'h49m'),
#  ('h07m', 'Atualizado', 'h49m', 'passe'),
#  ('Atualizado', 'h49m', 'passe', 'Eli'),
#  ('h49m', 'passe', 'Eli', 'Manning'),
#  ('passe', 'Eli', 'Manning', 'Plaxico'),
#  ('Eli', 'Manning', 'Plaxico', 'Burress'),
#  ('Manning', 'Plaxico', 'Burress', 'segundos'),
#  ('Plaxico', 'Burress', 'segundos', 'fim'),
# ...

# %%
#d) Retorne as entidades nomeadas do corpus, usando os bigramas e trigramas
print("Bigramas:")
lista = []
for bigrama in bigramas:
    if bigrama[0][0].isupper() and bigrama[1][0].isupper():
        lista.append(bigrama)
set(lista)
# Out:
# Bigramas:
# {('Amani', 'Toomer'),
#  ('Antonio', 'Pierce'),
#  ('Bill', 'Bellichick'),
#  ('Bowl', 'XLII'),
#  ('Brandon', 'Jacobs'),
#  ('David', 'Tyree'),
#  ('Eli', 'Manning'),
#  ('Ellis', 'Hobbs'),
#  ('England', 'Patriots'),
#  ('England', 'Quatro'),
#  ('Glendale', 'Super'),
#  ('Indianapolis', 'Colts'),
#  ('Jabar', 'Gaffney'),
#  ('Kevin', 'Boss'),
#  ('Kevin', 'Faulk'),
#  ('Laurence', 'Maroney'),
#  ('Lawrence', 'Tynes'),
#  ('Manning', 'Plaxico'),
#  ('Moss', 'Kevin'),
#  ('NFL', 'Indianapolis'),
#  ('New', 'England'),
#  ('New', 'York'),
#  ('Nova', 'York'),
#  ('Patriots', 'Giants'),
#  ('Patriots', 'Outro'),
#  ('Patriots', 'Super'),
#  ('Peyton', 'Manning'),
#  ('Plaxico', 'Burress'),
#  ('Randy', 'Moss'),
#  ('Steve', 'Smith'),
#  ('Super', 'Bowl'),
#  ('Tom', 'Brady'),
#  ('Welker', 'Randy'),
#  ('Wes', 'Welker'),
#  ('XLII', 'Azarões'),
#  ('York', 'Giants')}

# %%
lista2 = []
print("Trigramas:")
for trigrama in trigramas:
    if trigrama[0][0].isupper() and trigrama[1][0].isupper() and trigrama[2][0].isupper():
        lista2.append(trigrama)
set(lista2)
# Out:
# Trigramas:
# {('Bowl', 'XLII', 'Azarões'),
#  ('Eli', 'Manning', 'Plaxico'),
#  ('Glendale', 'Super', 'Bowl'),
#  ('Manning', 'Plaxico', 'Burress'),
#  ('Moss', 'Kevin', 'Faulk'),
#  ('NFL', 'Indianapolis', 'Colts'),
#  ('New', 'England', 'Patriots'),
#  ('New', 'England', 'Quatro'),
#  ('New', 'York', 'Giants'),
#  ('Patriots', 'Super', 'Bowl'),
#  ('Randy', 'Moss', 'Kevin'),
#  ('Super', 'Bowl', 'XLII'),
#  ('Welker', 'Randy', 'Moss'),
#  ('Wes', 'Welker', 'Randy')}

# %%
#e) Escolha 3 palavras do seu corpus e faça o stemming delas;
stemmer = nltk.RSLPStemmer() #RSLP Removedor de sufixos da lingua portuguesa
print(stemmer.stem('acabam'))
print(stemmer.stem('anotou'))
print(stemmer.stem('jogadas'))
# Out:
# acab
# anot
# jog

# %%
#f) Separe uma sentença do seu corpus e retorne todas as classes gramaticais das palavras da sentença 
#Analise se o etiquetador acertou todas as classes gramaticais

from nltk.tag import UnigramTagger
from nltk.tag import DefaultTagger

etiq_padrao = DefaultTagger('N')
setencas_treino = mac_morpho.tagged_sents()
etiquetador = UnigramTagger(setencas_treino, backoff=etiq_padrao)

etiquetado = etiquetador.tag(all_tokens[:23])

print(etiquetado)
# Out:
# [('Giants', 'NPROP'), ('batem', 'V'), ('os', 'ART'), ('Patriots', 'N'), ('no', 'KC'), ('Super', 'NPROP'), ('Bowl', 'NPROP'), ('XLII', 'N'), ('Azarões', 'N'), ('acabam', 'VAUX'), ('com', 'PREP'), ('a', 'ART'), ('invencibilidade', 'N'), ('de', 'PREP'), ('New', 'NPROP'), ('England', 'NPROP'), ('e', 'KC'), ('ficam', 'V'), ('com', 'PREP'), ('o', 'ART'), ('título', 'N'), ('da', 'NPROP'), ('temporada', 'N')]

# %%
#g) Retorne as classes gramaticais de todas as palavras do seu corpus

etiquetado_all = etiquetador.tag(all_tokens)

print(etiquetado_all)
# Out:
# [('Giants', 'NPROP'), ('batem', 'V'), ('os', 'ART'), ('Patriots', 'N'), ('no', 'KC'), ('Super', 'NPROP'), ('Bowl', 'NPROP'), ('XLII', 'N'), ('Azarões', 'N'), ('acabam', 'VAUX'), ('com', 'PREP'), ('a', 'ART'), ('invencibilidade', 'N'), ('de', 'PREP'), ('New', 'NPROP'), ('England', 'NPROP'), ('e', 'KC'), ('ficam', 'V'), ('com', 'PREP'), ('o', 'ART'), ('título', 'N'), ('da', 'NPROP'), ('temporada', 'N'), ('04/02/2008', 'N'), ('-', '-'), ('01h07m', 'N'), ('-', '-'), ('Atualizado', 'N'), ('em', 'PREP|+'), ('04/02/2008', 'N'), ('-', '-'), ('09h49m', 'N'), ('Com', 'PREP'), ('um', 'ART'), ('passe', 'N'), ('de', 'PREP'), ('Eli', 'NPROP'), ('Manning', 'NPROP'), ('para', 'PREP'), ('Plaxico', 'N'), ('Burress', 'N'), ('a', 'ART'), ('39', 'NUM'), ('segundos', 'N'), ('do', 'NPROP'), ('fim', 'N'), (',', ','), ('o', 'ART'), ('New', 'NPROP'), ('York', 'NPROP'), ('Giants', 'NPROP'), ('anotou', 'V'), ('o', 'ART'), ('touchdown', 'N|EST'), ('decisivo', 'ADJ'), ('e', 'KC'), ('derrubou', 'V'), ('o', 'ART'),
# ...

# %%
#h) Retorne as entidades nomeadas do seu corpus, usando a técnica de chunking
from nltk.chunk import RegexpParser

pattern = "NP: {<NPROP><NPROP> | <N><N>}"
analise_gramatical = RegexpParser(pattern)

arvore = analise_gramatical.parse(etiquetado_all)
print(arvore)
# Out:
# (S
#   Giants/NPROP
#   batem/V
#   os/ART
#   Patriots/N
#   no/KC
#   (NP Super/NPROP Bowl/NPROP)
#   (NP XLII/N Azarões/N)
#   acabam/VAUX
#   com/PREP
#   a/ART
#   invencibilidade/N
#   de/PREP
#   (NP New/NPROP England/NPROP)
#   e/KC
#   ficam/V
#   com/PREP
#   o/ART
#   título/N
#   da/NPROP
#   (NP temporada/N 04/02/2008/N)
#   -/-
#   01h07m/N
#   -/-
#   Atualizado/N
#   em/PREP|+
#   04/02/2008/N
#   -/-
#   09h49m/N
#   Com/PREP
#   um/ART
#   passe/N
#   de/PREP
#   (NP Eli/NPROP Manning/NPROP)
#   para/PREP
#   (NP Plaxico/N Burress/N)
#   a/ART
#   39/NUM
#   segundos/N
#   do/NPROP
#   fim/N
#   ,/,
#   o/ART
#   (NP New/NPROP York/NPROP)
#   Giants/NPROP
#   anotou/V
#   o/ART
#   touchdown/N|EST
#   decisivo/ADJ
#   e/KC
#   derrubou/V
#   o/ART
#   favorito/N
#   (NP New/NPROP England/NPROP)
#   Patriots/N
#   por/PREP|+
#   17/NUM
#   a/ART
#   14/NUM
#   (NP neste/N domingo/N)
#   ,/,
#   em/PREP|+
#   Glendale/N
#   ,/,
#   no/KC
# ...
